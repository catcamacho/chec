# %% [markdown]
# # dMRI Preprocessing
#
# This note book processes multiband diffusion weighted imaging for tensor-based analyses

# %%
from nipype.pipeline.engine import Workflow, Node, JoinNode, MapNode
from nipype.interfaces.utility import IdentityInterface, Function
from nipype.interfaces.io import SelectFiles, DataSink, FreeSurferSource
from nipype.interfaces.fsl.utils import Reorient2Std
from nipype.interfaces.fsl.epi import ApplyTOPUP, TOPUP
from nipype.interfaces.fsl.preprocess import MCFLIRT, FLIRT
from nipype.interfaces.freesurfer.preprocess import MRIConvert
from nipype.interfaces.freesurfer.model import Binarize
from nipype.interfaces.freesurfer import FSCommand

# MATLAB setup - Specify path to current SPM and the MATLAB's default mode
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('~/spm12/toolbox')
MatlabCommand.set_default_matlab_cmd("matlab -nodesktop -nosplash")

# FSL set up- change default file output type
from nipype.interfaces.fsl import FSLCommand
FSLCommand.set_default_output_type('NIFTI_GZ')

# Study-specific variables
project_home = '/moochie/Cat/EmoGrow/dMRI_proc'
output_dir = project_home + '/proc/preprocessing'
workflow_dir = project_home + '/workflows'
raw_dir = '/moochie/R01-EmoGrow/MRI_Data'
phase_encoding_file = project_home + '/misc/acq_params.txt'

#subjects_list = ['1000','1001','1002','1003','1004','1005','1006',
#                 '1007','1008','1009','1011','1012','1015','1016',
#                 '1017','1019','1021','1023','1025','1026', '1027','3000']
subjects_list = open(project_home + '/misc/emogrow_subjects.txt').read().splitlines()

#freesurfer setup
fs_dir = '/moochie/Cat/Aggregate_anats/subjects_dir'
FSCommand.set_default_subjects_dir(fs_dir)

# %%
### Universal nodes

# get subjects list
infosource = Node(IdentityInterface(fields=['subjid']),
                  name='infosource')
infosource.iterables = [('subjid', subjects_list)]

# Sink data of interest
substitutions = [('_subjid_', '')] #output file name substitutions
datasink = Node(DataSink(base_directory = output_dir,
                        container = output_dir,
                        substitutions = substitutions), 
                name='datasink')

# %% [markdown]
# ## Unwarping workflow

# %%
# Select func dicoms
def cvt_dicom(seqname,studypath,subjid):
    from nipype import logging, config
    config.enable_debug_mode()
    logging.update_logging(config)
    from glob import glob
    from nipype.interfaces.freesurfer import MRIConvert
    from os.path import abspath
    
    subjid = str(subjid)
    dicoms = glob('%s/%s/%s*/MR.*' % (studypath, subjid, seqname))
    print('%s/%s/%s*/MR.*' % (studypath, subjid, seqname))
    dicom_file=dicoms[0]
    
    cvt = MRIConvert()
    cvt.inputs.out_type = 'niigz'
    cvt.inputs.in_file = dicom_file
    cvt.inputs.out_file = seqname[0:13] + '.nii.gz'
    cvt.run()
    
    nii_file = abspath(seqname[0:13] + '.nii.gz')
    return(nii_file)

def sort_pes(pes):
    from nipype import logging, config
    config.enable_debug_mode()
    logging.update_logging(config)
    
    from nipype.interfaces.fsl import Merge, ExtractROI
    from os.path import abspath
    
    eroi = ExtractROI()
    eroi.inputs.t_min = 0
    eroi.inputs.t_size = 1
    
    for i in [0,1]:
        if 'dMRI_dir98_AP' in pes[i]:
            pe0 = pes[i]
            pe_AP = pes[i]
        elif 'dMRI_dir98_PA' in pes[i]:
            pe_PA = pes[i]
    
    eroi.inputs.in_file = pe_AP
    eroi.inputs.roi_file = 'dMRI_AP.nii.gz' 
    eroi.run()
    pe_AP_1 = abspath('dMRI_AP.nii.gz')
    
    eroi.inputs.in_file = pe_PA
    eroi.inputs.roi_file = 'dMRI_PA.nii.gz' 
    eroi.run()
    pe_PA_1 = abspath('dMRI_PA.nii.gz')
        
    
    me = Merge()
    me.inputs.in_files = [pe_AP_1,pe_PA_1]
    me.inputs.dimension='t'
    me.inputs.merged_file = 'merged_pes.nii.gz'
    me.run()
    
    merged_pes = abspath('merged_pes.nii.gz')

    return(merged_pes, pe0)

# %%
# select all dMRI sequences
selectdmri=Node(Function(input_names=['seqname','studypath','subjid'],
                         output_names=['nii_file'], 
                         function=cvt_dicom),
                name='selectdmri')
selectdmri.inputs.studypath = raw_dir
selectdmri.iterables = ('seqname',['dMRI_dir98_AP_14','dMRI_dir98_PA_14'])

# Sort the files for unwarping
sort_pe_list = JoinNode(Function(input_names=['pes'],
                                 output_names=['merged_pes','pe0'],
                                 function=sort_pes), 
                        name='sort_pe_list', joinsource='selectdmri', joinfield='pes')

# actually do the unwarping
topup =Node(TOPUP(encoding_file=phase_encoding_file), name='topup')

apply_topup = Node(ApplyTOPUP(in_index=[2], encoding_file=phase_encoding_file,
                              method='jac', out_corrected='dmri_unwarped.nii.gz'),
                   name='apply_topup')

# reorient unwarped image to MNI space standard
reorientdmri = Node(Reorient2Std(terminal_output='file'),
                    name='reorientdmri')

# %%
prepreprocflow = Workflow(name='prepreprocflow')
prepreprocflow.connect([(infosource,selectdmri, [('subjid','subjid')]),
                        (selectdmri,sort_pe_list, [('nii_file','pes')]),
                        (sort_pe_list,topup, [('merged_pes','in_file')]),
                        (topup, apply_topup, [('out_fieldcoef','in_topup_fieldcoef'), 
                                              ('out_movpar','in_topup_movpar')]),
                        (sort_pe_list, apply_topup, [('pe0','in_files')]),
                        (apply_topup, reorientdmri, [('out_corrected','in_file')]),
                        (reorientdmri, datasink, [('out_file','unwarped_funcs')])
                       ])

prepreprocflow.base_dir = workflow_dir
prepreprocflow.write_graph(graph2use='flat')
prepreprocflow.run('MultiProc', plugin_args={'n_procs': 4, 'memory_gb':10})
# Out:
# 190108-07:36:15,853 workflow INFO:
# 	 Generated workflow graph: /moochie/Cat/EmoGrow/dMRI_proc/workflows/prepreprocflow/graph.png (graph2use=flat, simple_form=True).
# 190108-07:36:15,892 workflow INFO:
# 	 Workflow prepreprocflow settings: ['check', 'execution', 'logging', 'monitoring']
# 190108-07:36:16,169 workflow INFO:
# 	 Running in parallel.
# 190108-07:36:16,184 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 58 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 4/4.
# 190108-07:36:16,357 workflow INFO:
# 	 [Job 0] Cached (prepreprocflow.selectdmri).
# 190108-07:36:16,427 workflow INFO:
# 	 [Job 1] Cached (prepreprocflow.selectdmri).
# 190108-07:36:16,523 workflow INFO:
# 	 [Job 2] Cached (prepreprocflow.selectdmri).
# 190108-07:36:16,553 workflow INFO:
# 	 [Job 3] Cached (prepreprocflow.selectdmri).
# 190108-07:36:18,187 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 54 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 4/4.
# 190108-07:36:18,317 workflow INFO:
# 	 [Job 4] Cached (prepreprocflow.selectdmri).
# 190108-07:36:18,367 workflow INFO:
# 	 [Job 5] Cached (prepreprocflow.selectdmri).
# 190108-07:36:18,418 workflow INFO:
# 	 [Job 11] Cached (prepreprocflow.selectdmri).
# 190108-07:36:18,442 workflow INFO:
# 	 [Job 12] Cached (prepreprocflow.selectdmri).
# 190108-07:36:20,190 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 51 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 4/4.
# 190108-07:36:20,380 workflow INFO:
# 	 [Job 6] Cached (prepreprocflow.sort_pe_list).
# 190108-07:36:20,444 workflow INFO:
# 	 [Job 13] Cached (prepreprocflow.selectdmri).
# 190108-07:36:20,534 workflow INFO:
# 	 [Job 14] Cached (prepreprocflow.selectdmri).
# 190108-07:36:20,574 workflow INFO:
# 	 [Job 20] Cached (prepreprocflow.selectdmri).
# 190108-07:36:22,191 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 49 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 4/4.
# 190108-07:36:22,308 workflow INFO:
# 	 [Job 7] Cached (prepreprocflow.topup).
# 190108-07:36:22,408 workflow INFO:
# 	 [Job 15] Cached (prepreprocflow.sort_pe_list).
# 190108-07:36:22,527 workflow INFO:
# 	 [Job 21] Cached (prepreprocflow.selectdmri).
# 190108-07:36:22,594 workflow INFO:
# 	 [Job 22] Cached (prepreprocflow.selectdmri).
# 190108-07:36:24,193 workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 47 jobs ready. Free memory (GB): 10.00/10.00, Free processors: 4/4.
# 190108-07:36:24,375 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.apply_topup".
# 190108-07:36:24,384 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.apply_topup" in "/moochie/Cat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_023/apply_topup".
# 190108-07:36:24,405 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.apply_topup".
# 190108-07:36:24,671 workflow INFO:
# 	 [Job 16] Cached (prepreprocflow.topup).
# 190108-07:36:24,770 workflow INFO:
# 	 [Job 23] Cached (prepreprocflow.selectdmri).
# 190108-07:36:24,868 workflow INFO:
# 	 [Job 29] Cached (prepreprocflow.selectdmri).
# 190108-07:36:25,155 workflow INFO:
# 	 [Node] Running "apply_topup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/moochie/Cat/EmoGrow/dMRI_proc/misc/acq_params.txt --imain=/moochie/Cat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_023/_seqname_dMRI_dir98_AP_14/selectdmri/dMRI_dir98_AP.nii.gz --inindex=2 --topup=/moochie/Cat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_023/apply_topup/merged_pes_base --method=jac --out=dmri_unwarped.nii.gz
# 190108-07:36:26,195 workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 46 jobs ready. Free memory (GB): 9.80/10.00, Free processors: 3/4.
#                      Currently running:
#                        * prepreprocflow.apply_topup
# 190108-07:36:34,298 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.apply_topup".
# 190108-07:36:34,307 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.apply_topup" in "/moochie/Cat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_012/apply_topup".
# 190108-07:36:34,662 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.apply_topup".
# 190108-07:36:43,207 workflow INFO:
# 	 [Job 24] Cached (prepreprocflow.sort_pe_list).
# 190108-07:36:43,329 workflow INFO:
# 	 [Job 30] Cached (prepreprocflow.sort_pe_list).
# 190108-07:36:43,340 workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 45 jobs ready. Free memory (GB): 9.60/10.00, Free processors: 2/4.
#                      Currently running:
#                        * prepreprocflow.apply_topup
#                        * prepreprocflow.apply_topup
# 190108-07:36:52,773 workflow INFO:
# 	 [Job 25] Cached (prepreprocflow.topup).
# 190108-07:36:52,987 workflow INFO:
# 	 [Job 31] Cached (prepreprocflow.topup).
# 190108-07:36:53,127 workflow INFO:
# 	 [Node] Running "apply_topup" ("nipype.interfaces.fsl.epi.ApplyTOPUP"), a CommandLine Interface with command:
# applytopup --datain=/moochie/Cat/EmoGrow/dMRI_proc/misc/acq_params.txt --imain=/moochie/Cat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_012/_seqname_dMRI_dir98_AP_14/selectdmri/dMRI_dir98_AP.nii.gz --inindex=2 --topup=/moochie/Cat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_012/apply_topup/merged_pes_base --method=jac --out=dmri_unwarped.nii.gz
# 190108-07:36:53,158 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.apply_topup".
# 190108-07:36:53,166 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.apply_topup" in "/moochie/Cat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_029/apply_topup".
# 190108-07:36:53,188 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.apply_topup".
# 190108-07:36:53,347 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.apply_topup".
# 190108-07:36:53,354 workflow INFO:
# 	 [Node] Setting-up "prepreprocflow.apply_topup" in "/moochie/Cat/EmoGrow/dMRI_proc/workflows/prepreprocflow/_subjid_013/apply_topup".
# 190108-07:36:53,468 workflow INFO:
# 	 [Node] Outdated cache found for "prepreprocflow.apply_topup".
# 190108-07:36:54,999 workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 43 jobs ready. Free memory (GB): 9.20/10.00, Free processors: 0/4.
#                      Currently running:
#                        * prepreprocflow.apply_topup
#                        * prepreprocflow.apply_topup
#                        * prepreprocflow.apply_topup
#                        * prepreprocflow.apply_topup

# %% [markdown]
# ## Preprocessing Workflow
#
# This workflow performs the following steps:
# *

# %%
# FreeSurferSource - Data grabber specific for FreeSurfer data
def FSid(subjid):
    from nipype import logging, config
    config.enable_debug_mode()
    logging.update_logging(config)
    
    fs_id = 'E'+str(subjid)
    return(fs_id)

fsid = Node(Function(input_names=['subjid'],
                     output_names=['fs_id'], 
                     function=FSid), 
            name='fsid')

fssource = Node(FreeSurferSource(subjects_dir=fs_dir),
                run_without_submitting=True,
                name='fssource')
